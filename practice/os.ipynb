# %%
import os

# %%
print(dir(os))
# Out:
# ['DirEntry', 'EX_OK', 'F_OK', 'GenericAlias', 'Mapping', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_walk', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync',
# ...

# %%
os.remove("Enrollment details.xlsx")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\moham\\Desktop\\pw-data-science\\practice'

# %%
# os.chdir("C:\\Users\\moham\\Desktop")
import sys
sys.path
# os.chdir()
# Out:
# ['C:\\Users\\moham\\Desktop\\pw-data-science',
#  'C:\\Program Files\\JetBrains\\PyCharm 2025.2\\plugins\\python-ce\\helpers\\pydev',
#  'C:\\Program Files\\JetBrains\\PyCharm 2025.2\\plugins\\python-ce\\helpers\\jupyter_debug',
#  'C:\\Users\\moham\\anaconda3\\envs\\pw-data-science\\python311.zip',
#  'C:\\Users\\moham\\anaconda3\\envs\\pw-data-science\\DLLs',
#  'C:\\Users\\moham\\anaconda3\\envs\\pw-data-science\\Lib',
#  'C:\\Users\\moham\\anaconda3\\envs\\pw-data-science',
#  '',
#  'C:\\Users\\moham\\anaconda3\\envs\\pw-data-science\\Lib\\site-packages',
#  'C:\\Users\\moham\\anaconda3\\envs\\pw-data-science\\Lib\\site-packages\\win32',
#  'C:\\Users\\moham\\anaconda3\\envs\\pw-data-science\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\moham\\anaconda3\\envs\\pw-data-science\\Lib\\site-packages\\Pythonwin']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\moham\\Desktop'

# %%
os.mkdir("one")

# %%
os.makedirs("two/three")
