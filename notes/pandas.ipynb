# %% [markdown]
# ## 1. Data Input & Basics
#
# ### Q1: How does `read_csv()` allow customization for loading specific columns or handling delimiters?
#
# **Approach**: Use `read_csv()` to load specific columns and inspect the dataset structure.
#
# **Task**: Load the Titanic dataset using Seaborn (or CSV from Kaggle). Select only `survived`, `pclass`, `sex`, `age` with `usecols`. Display the first 5 rows and dataset info using `head()` and `info()`.
#
# **Learning Outcome**: Learn to load data efficiently, select specific columns, and inspect DataFrame structure.

# %%
from unittest.mock import inplace

import numpy as np
import pandas as pd

#Below is error because you should pass in array
# df=pd.read_excel("../Resources/sales_data.xlsx",usecols="OrderID,CustomerName")

# df=pd.read_excel("../Resources/sales_data.xlsx",usecols=["OrderID","CustomerName"])

df=pd.read_excel("../Resources/sales_data.xlsx")

# %%
df
# Out:
#       OrderID CustomerName     Product     Category  Quantity  Price  \
# 0           1        Grace       Mouse    Wearables         7   1269
# 1           2        David    Keyboard    Wearables         1    875
# 2           3       Hannah  Headphones  Accessories         5    638
# 3           4          Eva      Tablet  Electronics         6    580
# 4           5        Grace     Monitor  Electronics         5   1135
# ...       ...          ...         ...          ...       ...    ...
# 4995     4996        Grace     Monitor  Accessories         6   1641
# 4996     4997        David  Headphones  Electronics         9   1420
# 4997     4998          Eva  Smartwatch  Electronics         3   1131
# 4998     4999      Charlie       Mouse  Accessories         8    204
# 4999     5000        David      Laptop    Wearables         7   1640
#
#                OrderDate Region  TotalSales
# 0    2020-01-01 00:00:00   East        8883
# 1    2020-01-01 01:00:00  North         875
# ...

# %%
df=pd.read_excel("../Resources/sales_data.xlsx")

# %%
df
# Out:
#       OrderID CustomerName     Product     Category  Quantity  Price  \
# 0           1        Grace       Mouse    Wearables         7   1269
# 1           2        David    Keyboard    Wearables         1    875
# 2           3       Hannah  Headphones  Accessories         5    638
# 3           4          Eva      Tablet  Electronics         6    580
# 4           5        Grace     Monitor  Electronics         5   1135
# ...       ...          ...         ...          ...       ...    ...
# 4995     4996        Grace     Monitor  Accessories         6   1641
# 4996     4997        David  Headphones  Electronics         9   1420
# 4997     4998          Eva  Smartwatch  Electronics         3   1131
# 4998     4999      Charlie       Mouse  Accessories         8    204
# 4999     5000        David      Laptop    Wearables         7   1640
#
#                OrderDate Region  TotalSales
# 0    2020-01-01 00:00:00   East        8883
# 1    2020-01-01 01:00:00  North         875
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       5000 non-null   int64
#  1   CustomerName  5000 non-null   object
#  2   Product       5000 non-null   object
#  3   Category      5000 non-null   object
#  4   Quantity      5000 non-null   int64
#  5   Price         5000 non-null   int64
#  6   OrderDate     5000 non-null   datetime64[ns]
#  7   Region        5000 non-null   object
#  8   TotalSales    5000 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 351.7+ KB

# %%
df.describe()
# Out:
#            OrderID     Quantity       Price            OrderDate    TotalSales
# count  5000.000000  5000.000000  5000.00000                 5000   5000.000000
# mean   2500.500000     4.959800  1036.63360  2020-04-14 03:30:00   5119.755600
# min       1.000000     1.000000    50.00000  2020-01-01 00:00:00     52.000000
# 25%    1250.750000     3.000000   551.75000  2020-02-22 01:45:00   1723.500000
# 50%    2500.500000     5.000000  1049.00000  2020-04-14 03:30:00   3962.500000
# 75%    3750.250000     7.000000  1531.00000  2020-06-05 05:15:00   7597.000000
# max    5000.000000     9.000000  1999.00000  2020-07-27 07:00:00  17901.000000
# std    1443.520003     2.581844   563.84487                  NaN   4109.375565

# %%
df['Category'].value_counts()
# Out:
# Category
# Electronics    1742
# Wearables      1632
# Accessories    1626
# Name: count, dtype: int64

# %%
# print(df.loc[7,"OrderID"])
import random
import numpy as np
for i in range(0,100):
    ranindex=random.randint(0,4999)
    df.loc[ranindex,"OrderID"]=np.nan

# %%
df.describe()
# Out:
#            OrderID     Quantity       Price            OrderDate    TotalSales
# count  4900.000000  5000.000000  5000.00000                 5000   5000.000000
# mean   2498.940612     4.959800  1036.63360  2020-04-14 03:30:00   5119.755600
# min       1.000000     1.000000    50.00000  2020-01-01 00:00:00     52.000000
# 25%    1246.750000     3.000000   551.75000  2020-02-22 01:45:00   1723.500000
# 50%    2497.500000     5.000000  1049.00000  2020-04-14 03:30:00   3962.500000
# 75%    3749.250000     7.000000  1531.00000  2020-06-05 05:15:00   7597.000000
# max    5000.000000     9.000000  1999.00000  2020-07-27 07:00:00  17901.000000
# std    1444.599397     2.581844   563.84487                  NaN   4109.375565

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       4900 non-null   float64
#  1   CustomerName  5000 non-null   object
#  2   Product       5000 non-null   object
#  3   Category      5000 non-null   object
#  4   Quantity      5000 non-null   int64
#  5   Price         5000 non-null   int64
#  6   OrderDate     5000 non-null   datetime64[ns]
#  7   Region        5000 non-null   object
#  8   TotalSales    5000 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 351.7+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.lineplot(x="Quantity",y="Price",data=df)
# Out:
# <Axes: xlabel='Quantity', ylabel='Price'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.drop("PassengerId", axis=1 ,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x="Sex", y="Survived", data=df)
plt.show()

# %%
sns.barplot(x="Pclass", y="Survived", data=df)
plt.show()

# %%
sns.heatmap()
