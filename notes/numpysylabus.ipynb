# %% [markdown]
# # 🛤️ Complete NumPy Roadmap (Beginner → Advanced)
#
# ---
#
# ## 1. **Getting Started**
#
# * Install: `pip install numpy`
# * Import: `import numpy as np`
# * What is NumPy? Why it’s faster than Python lists.
#
# ---
#
# ## 2. **Creating Arrays**
#
# * `np.array([1,2,3])` – basic array creation
# * `np.zeros()`, `np.ones()`, `np.full()`
# * `np.arange(start, stop, step)`
# * `np.linspace(start, stop, num)`
# * Random arrays:
#
#   * `np.random.rand()` – uniform distribution
#   * `np.random.randn()` – normal distribution
#   * `np.random.randint()` – random integers
#
# ✅ Practice: Generate random 1D, 2D, 3D arrays.
#
# ---
#
# ## 3. **Array Attributes**
#
# * `shape` – dimensions of array
# * `size` – total number of elements
# * `ndim` – number of dimensions
# * `dtype`, `itemsize`
# * Reshape rule: if `a*b = x`, then `c*d = x` must hold.
#
#   * `reshape()`
#   * `reshape.base` → shows if reshaped array is a **view** of the original.
#
# ✅ Practice: Check `.base` after reshape and slicing.
#
# ---
#
# ## 4. **Indexing & Slicing**
#
# * Simple indexing: `arr[0]`, `arr[-1]`
# * 2D indexing: `arr[0,1]`, `arr[1,:]`, `arr[:,2]`
# * Fancy indexing: `arr[[0,2,4]]`
# * Boolean indexing:
#
#   * `arr[arr > 5]`
#   * `np.array(condition)`
#
# ✅ Practice: Select rows, columns, and subsets.
#
# ---
#
# ## 5. **Array Manipulation**
#
# * Flatten:
#
#   * `ravel()` (view if possible)
#   * `flatten()` (always copy)
# * Expand dimension:
#
#   * `np.expand_dims(arr, axis=0)`
# * Squeeze dimension:
#
#   * `np.squeeze(arr)`
# * Repeat & tile:
#
#   * `np.repeat(arr, n)`
#   * `np.tile(arr, (m,n))`
# * Stacking: `hstack`, `vstack`
# * Splitting: `np.split(arr, n)`
#
# ---
#
# ## 6. **Arithmetic & Mathematical Operations**
#
# * Element-wise: `+`, `-`, `*`, `/`, `**`
# * UFuncs (universal functions):
#
#   * `np.sin`, `np.cos`, `np.tan`
#   * `np.log`, `np.exp`, `np.power`
#   * `np.sqrt`
# * Aggregate functions:
#
#   * `np.sum`, `np.mean`, `np.std`, `np.var`
#   * `np.min`, `np.max`, `np.argmin`, `np.argmax`
#   * `np.count_nonzero`
# * Sorting: `np.sort`, `np.argsort`
#
# ---
#
# ## 7. **Broadcasting**
#
# * Rules of broadcasting
# * Scalar with array
# * Vector with matrix
# * Example: normalizing data
#
# ✅ Goal: Avoid loops, use broadcasting.
#
# ---
#
# ## 8. **Linear Algebra**
#
# * Dot product: `np.dot(a, b)` or `a @ b`
# * Matrix multiplication: `np.matmul`
# * Determinant: `np.linalg.det`
# * Inverse: `np.linalg.inv`
# * Eigenvalues & eigenvectors: `np.linalg.eig`
# * Solve system of equations: `np.linalg.solve`
#
# ---
#
# ## 9. **Transpose & Axis Operations**
#
# * `.T` – transpose
# * `swapaxes(arr, 0, 1)`
# * `moveaxis`
# * Aggregations with axis: `np.sum(arr, axis=0)`
#
# ---
#
# ## 10. **Random & Simulation**
#
# * `np.random.rand()`, `np.random.randn()`
# * `np.random.randint(low, high, size)`
# * `np.random.choice()`
# * `np.random.permutation()`
# * Seeding for reproducibility: `np.random.seed(42)`
#
# ---
#
# ## 11. **String Operations**
#
# * `np.char.add(arr1, arr2)`
# * `np.char.multiply("Hi", 3)`
# * `np.char.lower`, `np.char.upper`
# * `np.char.replace("text", "old", "new")`
# * `np.char.split("string")`
#
# ✅ Useful for text preprocessing in datasets.
#
# ---
#
# ## 12. **Performance & Optimization**
#
# * Vectorization vs loops → timing comparison
# * `np.vectorize()` (syntactic sugar, not true speedup)
# * Memory layout: `C_CONTIGUOUS` vs `F_CONTIGUOUS`
# * Efficient reshaping vs copying
#
# ---
#
# ## 13. **Integration with Other Libraries**
#
# * **Pandas** → DataFrames built on NumPy
# * **Matplotlib/Seaborn** → visualization needs arrays
# * **Scikit-learn** → ML models accept NumPy arrays
# * **TensorFlow/PyTorch** → heavily inspired by NumPy
#
# ---
#
# ## 14. **Projects for Practice**
#
# * Simple Linear Regression from scratch (no sklearn)
# * Monte Carlo simulation to estimate π
# * Image manipulation (grayscale, flip, rotate)
# * Stock price random walk simulation
# * Dataset preprocessing for ML
#
# ---
#
# # 📅 Suggested Timeline
#
# * **Week 1:** Basics, creation, indexing, attributes
# * **Week 2:** Reshape, flatten, expand/squeeze, repeat, string ops
# * **Week 3:** Arithmetic, broadcasting, random, transpose
# * **Week 4:** Linear algebra, optimization, mini projects
#
# ---
#
# ✅ Now this roadmap **explicitly covers all your listed concepts** (reshape.base, expand/squeeze, repeat, string ops, linalg, etc.).
#
# Would you like me to also make a **daily 30-day study plan** from this roadmap (with tasks + small exercises per day), so you can track progress easily?
