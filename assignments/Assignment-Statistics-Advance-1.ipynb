# %% [markdown]
# # Assignment : Statistics Advance - 1

# %% [markdown]
# ### **Question 1: What is a random variable in probability theory?**
#
#
#
# ### **Answer:**
#
# In probability theory, a **random variable** is a variable that represents the possible outcomes of a random experiment. It assigns a numerical value to each outcome in the sample space.
#
# There are two main types of random variables:
#
# 1. **Discrete Random Variable:** Takes a countable number of values (e.g., number of heads in 3 coin tosses).
# 2. **Continuous Random Variable:** Takes an infinite number of possible values within a range (e.g., height, time, temperature).
#
# Mathematically, a random variable is a function that maps outcomes of an experiment to real numbers.
#
# For example:
# If we toss a coin,
#
# * Let ( X = 1 ) if it’s heads
# * Let ( X = 0 ) if it’s tails
#
# Here, ( X ) is a random variable.
#
# ---
#
# ### **Example in Python**

# %%
import random

# Simulate a coin toss random variable
def coin_toss():
    outcome = random.choice(['Heads', 'Tails'])
    X = 1 if outcome == 'Heads' else 0
    return X, outcome

X_value, outcome = coin_toss()
print(f"Outcome: {outcome}, Random Variable X: {X_value}")
# Out:
# Outcome: Heads, Random Variable X: 1

# %% [markdown]
# ### **Question 2: What are the types of random variables?**
#
# ### **Answer:**
#
# Random variables are classified into **two main types** based on the nature of the outcomes they represent:
#
# 1. **Discrete Random Variable**
#
#    * A discrete random variable can take **only specific, countable values**.
#    * Examples:
#
#      * Number of heads when flipping three coins (possible values: 0, 1, 2, 3).
#      * Number of students present in a class.
#    * Its probability distribution is represented using a **probability mass function (PMF)**, which gives the probability of each possible value.
#
# 2. **Continuous Random Variable**
#
#    * A continuous random variable can take **any value within a given range or interval**.
#    * Examples:
#
#      * The height of students in a class.
#      * The time taken to complete a task.
#    * Its probability distribution is represented using a **probability density function (PDF)**, and the probability of any single exact value is zero (only ranges have probabilities).
#
# ---
#
# ### **Python Example:**

# %%
import random
import numpy as np

# Example of a discrete random variable (Dice roll)
dice_roll = random.randint(1, 6)
print(f"Discrete Random Variable (Dice Roll): {dice_roll}")

# Example of a continuous random variable (Random float between 0 and 1)
continuous_value = np.random.random()
print(f"Continuous Random Variable (Random Float): {continuous_value}")
# Out:
# Discrete Random Variable (Dice Roll): 1
# Continuous Random Variable (Random Float): 0.16604611648948997

# %% [markdown]
# ### **Question 3: Explain the difference between discrete and continuous distributions.**
#
# ### **Answer:**
#
# In probability theory, **discrete** and **continuous** distributions describe how probabilities are assigned to the outcomes of **discrete** and **continuous** random variables, respectively.
#
# | **Feature**                     | **Discrete Distribution**                                                                                   | **Continuous Distribution**                                                                             |
# | ------------------------------- | ----------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------- |
# | **Definition**                  | Describes probabilities for **discrete random variables** that take a finite or countable number of values. | Describes probabilities for **continuous random variables** that can take any value within a range.     |
# | **Representation Function**     | **Probability Mass Function (PMF)**                                                                         | **Probability Density Function (PDF)**                                                                  |
# | **Probability of Single Value** | Each specific value has a non-zero probability, i.e., ( P(X = x) > 0 ).                                     | The probability of any exact value is zero, i.e., ( P(X = x) = 0 ); only ranges have probabilities.     |
# | **Example**                     | Rolling a dice — outcomes {1, 2, 3, 4, 5, 6}.                                                               | Measuring the height of people — possible values form a continuous range (e.g., 150.1 cm, 150.2 cm, …). |
# | **Graph**                       | Represented by bars for each outcome.                                                                       | Represented by a smooth curve (area under the curve = 1).                                               |
#
# ---
#
# ### **Python Example:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Discrete distribution example (Dice roll probabilities)
x_discrete = [1, 2, 3, 4, 5, 6]
p_discrete = [1/6] * 6
plt.bar(x_discrete, p_discrete)
plt.title("Discrete Distribution - Dice Roll")
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.show()

# Continuous distribution example (Normal distribution)
x_continuous = np.linspace(-3, 3, 100)
y_continuous = (1/np.sqrt(2*np.pi)) * np.exp(-0.5 * x_continuous**2)
plt.plot(x_continuous, y_continuous)
plt.title("Continuous Distribution - Normal Curve")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ### **Question 4: What is a binomial distribution, and how is it used in probability?**
#
# ### **Answer:**
#
# A **binomial distribution** is a **discrete probability distribution** that describes the number of **successes** in a fixed number of independent trials, where each trial has only **two possible outcomes** — success or failure.
#
# It is one of the most commonly used probability distributions in statistics and probability theory.
#
# #### **Key Characteristics:**
#
# 1. The experiment consists of a fixed number of trials (( n )).
# 2. Each trial has only two outcomes: success (with probability ( p )) or failure (with probability ( q = 1 - p )).
# 3. The trials are **independent** of each other.
# 4. The random variable ( X ) represents the **number of successes** in ( n ) trials.
#
# #### **Probability Formula:**
#
# [
# P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}
# ]
# Where:
#
# * ( n ) = number of trials
# * ( k ) = number of successes
# * ( p ) = probability of success in one trial
# * ( \binom{n}{k} ) = combination (n choose k)
#
# #### **Example:**
#
# If you toss a fair coin 5 times, and you want to find the probability of getting exactly 3 heads:
# [
# P(X = 3) = \binom{5}{3} (0.5)^3 (0.5)^2 = 10 \times 0.125 \times 0.25 = 0.3125
# ]
#
# #### **Applications:**
#
# * Quality control (e.g., defective items in a batch)
# * Survey results (e.g., number of people saying “yes”)
# * Coin toss experiments or games involving binary outcomes
#
# ---
#
# ### **Python Example:**

# %%
from scipy.stats import binom

# Parameters
n = 5   # number of trials
p = 0.5 # probability of success

# Probability of getting exactly 3 successes
k = 3
prob = binom.pmf(k, n, p)
print(f"P(X = 3) = {prob}")

# Generate distribution for all possible values
import matplotlib.pyplot as plt

x = range(n + 1)
y = binom.pmf(x, n, p)
plt.bar(x, y)
plt.title("Binomial Distribution (n=5, p=0.5)")
plt.xlabel("Number of Successes (k)")
plt.ylabel("Probability P(X=k)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from scipy.stats import binom
#       3 # Parameters
#       4 n = 5   # number of trials
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\stats\__init__.py:626
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    621
#     622 """  # noqa: E501
#     624 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     625                                DegenerateDataWarning, FitError)
# --> 626 from ._stats_py import *
#     627 from ._variation import variation
#     628 from .distributions import *
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\stats\_stats_py.py:39
#      36 import numpy as np
#      37 from numpy import array, asarray, ma
# ---> 39 from scipy import sparse
#      40 from scipy.spatial import distance_matrix
#      42 from scipy.optimize import milp, LinearConstraint
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\__init__.py:131, in __getattr__(name)
#     129 def __getattr__(name):
#     130     if name in submodules:
# --> 131         return _importlib.import_module(f'scipy.{name}')
#     132     else:
#     133         try:
#
# File ~\anaconda3\envs\pw-data-science\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\sparse\__init__.py:304
#     301 import warnings as _warnings
#     302 import importlib as _importlib
# --> 304 from ._base import *
#     305 from ._csr import *
#     306 from ._csc import *
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\sparse\_base.py:8
#       5 import numpy as np
#       6 import operator
# ----> 8 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       9                        get_sum_dtype, isdense, isscalarlike, _todata,
#      10                        matrix, validateaxis, getdtype, is_pydata_spmatrix)
#      11 from scipy._lib._sparse import SparseABC, issparse
#      13 from ._matrix import spmatrix
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\sparse\_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\_lib\_util.py:14
#      11 from typing import Literal, TypeAlias, TypeVar
#      13 import numpy as np
# ---> 14 from scipy._lib._array_api import (Array, array_namespace, is_lazy_array,
#      15                                    is_numpy, is_marray, xp_result_device,
#      16                                    xp_size, xp_result_type)
#      17 from scipy._lib._docscrape import FunctionDoc, Parameter
#      18 from scipy._lib._sparse import issparse
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\_lib\_array_api.py:25
#      22 import numpy.typing as npt
#      24 from scipy._lib import array_api_compat
# ---> 25 from scipy._lib.array_api_compat import (
#      26     is_array_api_obj,
#      27     is_lazy_array,
#      28     size as xp_size,
#      29     numpy as np_compat,
#      30     device as xp_device,
#      31     is_numpy_namespace as is_numpy,
#      32     is_cupy_namespace as is_cupy,
#      33     is_torch_namespace as is_torch,
#      34     is_jax_namespace as is_jax,
#      35     is_dask_namespace as is_dask,
#      36     is_array_api_strict_namespace as is_array_api_strict
#      37 )
#      38 from scipy._lib._sparse import issparse
#      39 from scipy._lib._docscrape import FunctionDoc
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\_lib\array_api_compat\numpy\__init__.py:4
#       1 # ruff: noqa: PLC0414
#       2 from typing import Final
# ----> 4 from numpy import *  # noqa: F403  # pyright: ignore[reportWildcardImportFromLibrary]
#       6 # from numpy import * doesn't overwrite these builtin names
#       7 from numpy import abs as abs
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\__init__.py:367, in __getattr__(attr)
#     117     raise ImportError(msg) from e
#     119 from . import _core
#     120 from ._core import (
#     121     False_,
#     122     ScalarType,
#     123     True_,
#     124     abs,
#     125     absolute,
#     126     acos,
#     127     acosh,
#     128     add,
#     129     all,
#     130     allclose,
#     131     amax,
#     132     amin,
#     133     any,
#     134     arange,
#     135     arccos,
#     136     arccosh,
#     137     arcsin,
#     138     arcsinh,
#     139     arctan,
#     140     arctan2,
#     141     arctanh,
#     142     argmax,
#     143     argmin,
#     144     argpartition,
#     145     argsort,
#     146     argwhere,
#     147     around,
#     148     array,
#     149     array2string,
#     150     array_equal,
#     151     array_equiv,
#     152     array_repr,
#     153     array_str,
#     154     asanyarray,
#     155     asarray,
#     156     ascontiguousarray,
#     157     asfortranarray,
#     158     asin,
#     159     asinh,
#     160     astype,
#     161     atan,
#     162     atan2,
#     163     atanh,
#     164     atleast_1d,
#     165     atleast_2d,
#     166     atleast_3d,
#     167     base_repr,
#     168     binary_repr,
#     169     bitwise_and,
#     170     bitwise_count,
#     171     bitwise_invert,
#     172     bitwise_left_shift,
#     173     bitwise_not,
#     174     bitwise_or,
#     175     bitwise_right_shift,
#     176     bitwise_xor,
#     177     block,
#     178     bool,
#     179     bool_,
#     180     broadcast,
#     181     busday_count,
#     182     busday_offset,
#     183     busdaycalendar,
#     184     byte,
#     185     bytes_,
#     186     can_cast,
#     187     cbrt,
#     188     cdouble,
#     189     ceil,
#     190     character,
#     191     choose,
#     192     clip,
#     193     clongdouble,
#     194     complex64,
#     195     complex128,
#     196     complexfloating,
#     197     compress,
#     198     concat,
#     199     concatenate,
#     200     conj,
#     201     conjugate,
#     202     convolve,
#     203     copysign,
#     204     copyto,
#     205     correlate,
#     206     cos,
#     207     cosh,
#     208     count_nonzero,
#     209     cross,
#     210     csingle,
#     211     cumprod,
#     212     cumsum,
#     213     cumulative_prod,
#     214     cumulative_sum,
#     215     datetime64,
#     216     datetime_as_string,
#     217     datetime_data,
#     218     deg2rad,
#     219     degrees,
#     220     diagonal,
#     221     divide,
#     222     divmod,
#     223     dot,
#     224     double,
#     225     dtype,
#     226     e,
#     227     einsum,
#     228     einsum_path,
#     229     empty,
#     230     empty_like,
#     231     equal,
#     232     errstate,
#     233     euler_gamma,
#     234     exp,
#     235     exp2,
#     236     expm1,
#     237     fabs,
#     238     finfo,
#     239     flatiter,
#     240     flatnonzero,
#     241     flexible,
#     242     float16,
#     243     float32,
#     244     float64,
#     245     float_power,
#     246     floating,
#     247     floor,
#     248     floor_divide,
#     249     fmax,
#     250     fmin,
#     251     fmod,
#     252     format_float_positional,
#     253     format_float_scientific,
#     254     frexp,
#     255     from_dlpack,
#     256     frombuffer,
#     257     fromfile,
#     258     fromfunction,
#     259     fromiter,
#     260     frompyfunc,
#     261     fromstring,
#     262     full,
#     263     full_like,
#     264     gcd,
#     265     generic,
#     266     geomspace,
#     267     get_printoptions,
#     268     getbufsize,
#     269     geterr,
#     270     geterrcall,
#     271     greater,
#     272     greater_equal,
#     273     half,
#     274     heaviside,
#     275     hstack,
#     276     hypot,
#     277     identity,
#     278     iinfo,
#     279     indices,
#     280     inexact,
#     281     inf,
#     282     inner,
#     283     int8,
#     284     int16,
#     285     int32,
#     286     int64,
#     287     int_,
#     288     intc,
#     289     integer,
#     290     intp,
#     291     invert,
#     292     is_busday,
#     293     isclose,
#     294     isdtype,
#     295     isfinite,
#     296     isfortran,
#     297     isinf,
#     298     isnan,
#     299     isnat,
#     300     isscalar,
#     301     issubdtype,
#     302     lcm,
#     303     ldexp,
#     304     left_shift,
#     305     less,
#     306     less_equal,
#     307     lexsort,
#     308     linspace,
#     309     little_endian,
#     310     log,
#     311     log1p,
#     312     log2,
#     313     log10,
#     314     logaddexp,
#     315     logaddexp2,
#     316     logical_and,
#     317     logical_not,
#     318     logical_or,
#     319     logical_xor,
#     320     logspace,
#     321     long,
#     322     longdouble,
#     323     longlong,
#     324     matmul,
#     325     matrix_transpose,
#     326     matvec,
#     327     max,
#     328     maximum,
#     329     may_share_memory,
#     330     mean,
#     331     memmap,
#     332     min,
#     333     min_scalar_type,
#     334     minimum,
#     335     mod,
#     336     modf,
#     337     moveaxis,
#     338     multiply,
#     339     nan,
#     340     ndarray,
#     341     ndim,
#     342     nditer,
#     343     negative,
#     344     nested_iters,
#     345     newaxis,
#     346     nextafter,
#     347     nonzero,
#     348     not_equal,
#     349     number,
#     350     object_,
#     351     ones,
#     352     ones_like,
#     353     outer,
#     354     partition,
#     355     permute_dims,
#     356     pi,
#     357     positive,
#     358     pow,
#     359     power,
#     360     printoptions,
#     361     prod,
#     362     promote_types,
#     363     ptp,
#     364     put,
#     365     putmask,
#     366     rad2deg,
# --> 367     radians,
#     368     ravel,
#     369     recarray,
#     370     reciprocal,
#     371     record,
#     372     remainder,
#     373     repeat,
#     374     require,
#     375     reshape,
#     376     resize,
#     377     result_type,
#     378     right_shift,
#     379     rint,
#     380     roll,
#     381     rollaxis,
#     382     round,
#     383     sctypeDict,
#     384     searchsorted,
#     385     set_printoptions,
#     386     setbufsize,
#     387     seterr,
#     388     seterrcall,
#     389     shape,
#     390     shares_memory,
#     391     short,
#     392     sign,
#     393     signbit,
#     394     signedinteger,
#     395     sin,
#     396     single,
#     397     sinh,
#     398     size,
#     399     sort,
#     400     spacing,
#     401     sqrt,
#     402     square,
#     403     squeeze,
#     404     stack,
#     405     std,
#     406     str_,
#     407     subtract,
#     408     sum,
#     409     swapaxes,
#     410     take,
#     411     tan,
#     412     tanh,
#     413     tensordot,
#     414     timedelta64,
#     415     trace,
#     416     transpose,
#     417     true_divide,
#     418     trunc,
#     419     typecodes,
#     420     ubyte,
#     421     ufunc,
#     422     uint,
#     423     uint8,
#     424     uint16,
#     425     uint32,
#     426     uint64,
#     427     uintc,
#     428     uintp,
#     429     ulong,
#     430     ulonglong,
#     431     unsignedinteger,
#     432     unstack,
#     433     ushort,
#     434     var,
#     435     vdot,
#     436     vecdot,
#     437     vecmat,
#     438     void,
#     439     vstack,
#     440     where,
#     441     zeros,
#     442     zeros_like,
#     443 )
#     445 # NOTE: It's still under discussion whether these aliases
#     446 # should be removed.
#     447 for ta in ["float96", "float128", "complex192", "complex256"]:
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\char\__init__.py:1
# ----> 1 from numpy._core.defchararray import *
#       2 from numpy._core.defchararray import __all__, __doc__
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\_core\defchararray.py:23
#      21 from numpy._core import overrides
#      22 from numpy._core.multiarray import compare_chararrays
# ---> 23 from numpy._core.strings import (
#      24     _join as join,
#      25 )
#      26 from numpy._core.strings import (
#      27     _rsplit as rsplit,
#      28 )
#      29 from numpy._core.strings import (
#      30     _split as split,
#      31 )
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\_core\strings.py:24
#      22 from numpy._core.multiarray import _vec_string
#      23 from numpy._core.overrides import array_function_dispatch, set_module
# ---> 24 from numpy._core.umath import (
#      25     _center,
#      26     _expandtabs,
#      27     _expandtabs_length,
#      28     _ljust,
#      29     _lstrip_chars,
#      30     _lstrip_whitespace,
#      31     _partition,
#      32     _partition_index,
#      33     _replace,
#      34     _rjust,
#      35     _rpartition,
#      36     _rpartition_index,
#      37     _rstrip_chars,
#      38     _rstrip_whitespace,
#      39     _slice,
#      40     _strip_chars,
#      41     _strip_whitespace,
#      42     _zfill,
#      43     isalnum,
#      44     isalpha,
#      45     isdecimal,
#      46     isdigit,
#      47     islower,
#      48     isnumeric,
#      49     isspace,
#      50     istitle,
#      51     isupper,
#      52     str_len,
#      53 )
#      54 from numpy._core.umath import (
#      55     count as _count_ufunc,
#      56 )
#      57 from numpy._core.umath import (
#      58     endswith as _endswith_ufunc,
#      59 )
#
# ImportError: cannot import name '_center' from 'numpy._core.umath' (C:\Users\moham\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\_core\umath.py)

# %% [markdown]
# ### **Question 5: What is the standard normal distribution, and why is it important?**
#
# ### **Answer:**
#
# The **standard normal distribution** is a **special case of the normal distribution** where the **mean (μ) = 0** and the **standard deviation (σ) = 1**. It is also known as the **Z-distribution**.
#
# It is a **continuous probability distribution** that is **symmetric about the mean** and has a **bell-shaped curve**.
#
# #### **Probability Density Function (PDF):**
#
# [
# f(z) = \frac{1}{\sqrt{2\pi}} e^{-\frac{z^2}{2}}
# ]
# Where:
#
# * ( z ) is the standard score (Z-score),
# * ( e ) is the base of the natural logarithm (≈ 2.71828).
#
# ---
#
# ### **Importance of the Standard Normal Distribution:**
#
# 1. **Foundation for Statistical Inference:**
#    It is used to calculate probabilities and make inferences about data that follow a normal distribution.
#
# 2. **Z-Scores and Standardization:**
#    Any normal distribution can be **converted to a standard normal distribution** using the Z-score formula:
#    [
#    Z = \frac{X - \mu}{\sigma}
#    ]
#    This process helps in comparing data from different normal distributions.
#
# 3. **Simplifies Probability Calculations:**
#    Since the total area under the curve equals 1, probabilities can be easily found using **Z-tables**.
#
# 4. **Used in Hypothesis Testing and Confidence Intervals:**
#    The standard normal distribution plays a key role in calculating **p-values**, **critical values**, and **confidence levels** in hypothesis testing.
#
# ---
#
# ### **Python Example:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define range for z-values
z = np.linspace(-4, 4, 100)
pdf = norm.pdf(z, 0, 1)  # mean=0, std=1

plt.plot(z, pdf)
plt.title("Standard Normal Distribution (μ=0, σ=1)")
plt.xlabel("Z-Score")
plt.ylabel("Probability Density")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from scipy.stats import norm
#       5 # Define range for z-values
#       6 z = np.linspace(-4, 4, 100)
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\stats\__init__.py:626
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    621
#     622 """  # noqa: E501
#     624 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     625                                DegenerateDataWarning, FitError)
# --> 626 from ._stats_py import *
#     627 from ._variation import variation
#     628 from .distributions import *
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\stats\_stats_py.py:39
#      36 import numpy as np
#      37 from numpy import array, asarray, ma
# ---> 39 from scipy import sparse
#      40 from scipy.spatial import distance_matrix
#      42 from scipy.optimize import milp, LinearConstraint
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\__init__.py:131, in __getattr__(name)
#     129 def __getattr__(name):
#     130     if name in submodules:
# --> 131         return _importlib.import_module(f'scipy.{name}')
#     132     else:
#     133         try:
#
# File ~\anaconda3\envs\pw-data-science\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\sparse\__init__.py:304
#     301 import warnings as _warnings
#     302 import importlib as _importlib
# --> 304 from ._base import *
#     305 from ._csr import *
#     306 from ._csc import *
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\sparse\_base.py:8
#       5 import numpy as np
#       6 import operator
# ----> 8 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       9                        get_sum_dtype, isdense, isscalarlike, _todata,
#      10                        matrix, validateaxis, getdtype, is_pydata_spmatrix)
#      11 from scipy._lib._sparse import SparseABC, issparse
#      13 from ._matrix import spmatrix
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\sparse\_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\_lib\_util.py:14
#      11 from typing import Literal, TypeAlias, TypeVar
#      13 import numpy as np
# ---> 14 from scipy._lib._array_api import (Array, array_namespace, is_lazy_array,
#      15                                    is_numpy, is_marray, xp_result_device,
#      16                                    xp_size, xp_result_type)
#      17 from scipy._lib._docscrape import FunctionDoc, Parameter
#      18 from scipy._lib._sparse import issparse
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\_lib\_array_api.py:25
#      22 import numpy.typing as npt
#      24 from scipy._lib import array_api_compat
# ---> 25 from scipy._lib.array_api_compat import (
#      26     is_array_api_obj,
#      27     is_lazy_array,
#      28     size as xp_size,
#      29     numpy as np_compat,
#      30     device as xp_device,
#      31     is_numpy_namespace as is_numpy,
#      32     is_cupy_namespace as is_cupy,
#      33     is_torch_namespace as is_torch,
#      34     is_jax_namespace as is_jax,
#      35     is_dask_namespace as is_dask,
#      36     is_array_api_strict_namespace as is_array_api_strict
#      37 )
#      38 from scipy._lib._sparse import issparse
#      39 from scipy._lib._docscrape import FunctionDoc
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\scipy\_lib\array_api_compat\numpy\__init__.py:4
#       1 # ruff: noqa: PLC0414
#       2 from typing import Final
# ----> 4 from numpy import *  # noqa: F403  # pyright: ignore[reportWildcardImportFromLibrary]
#       6 # from numpy import * doesn't overwrite these builtin names
#       7 from numpy import abs as abs
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\__init__.py:367, in __getattr__(attr)
#     117     raise ImportError(msg) from e
#     119 from . import _core
#     120 from ._core import (
#     121     False_,
#     122     ScalarType,
#     123     True_,
#     124     abs,
#     125     absolute,
#     126     acos,
#     127     acosh,
#     128     add,
#     129     all,
#     130     allclose,
#     131     amax,
#     132     amin,
#     133     any,
#     134     arange,
#     135     arccos,
#     136     arccosh,
#     137     arcsin,
#     138     arcsinh,
#     139     arctan,
#     140     arctan2,
#     141     arctanh,
#     142     argmax,
#     143     argmin,
#     144     argpartition,
#     145     argsort,
#     146     argwhere,
#     147     around,
#     148     array,
#     149     array2string,
#     150     array_equal,
#     151     array_equiv,
#     152     array_repr,
#     153     array_str,
#     154     asanyarray,
#     155     asarray,
#     156     ascontiguousarray,
#     157     asfortranarray,
#     158     asin,
#     159     asinh,
#     160     astype,
#     161     atan,
#     162     atan2,
#     163     atanh,
#     164     atleast_1d,
#     165     atleast_2d,
#     166     atleast_3d,
#     167     base_repr,
#     168     binary_repr,
#     169     bitwise_and,
#     170     bitwise_count,
#     171     bitwise_invert,
#     172     bitwise_left_shift,
#     173     bitwise_not,
#     174     bitwise_or,
#     175     bitwise_right_shift,
#     176     bitwise_xor,
#     177     block,
#     178     bool,
#     179     bool_,
#     180     broadcast,
#     181     busday_count,
#     182     busday_offset,
#     183     busdaycalendar,
#     184     byte,
#     185     bytes_,
#     186     can_cast,
#     187     cbrt,
#     188     cdouble,
#     189     ceil,
#     190     character,
#     191     choose,
#     192     clip,
#     193     clongdouble,
#     194     complex64,
#     195     complex128,
#     196     complexfloating,
#     197     compress,
#     198     concat,
#     199     concatenate,
#     200     conj,
#     201     conjugate,
#     202     convolve,
#     203     copysign,
#     204     copyto,
#     205     correlate,
#     206     cos,
#     207     cosh,
#     208     count_nonzero,
#     209     cross,
#     210     csingle,
#     211     cumprod,
#     212     cumsum,
#     213     cumulative_prod,
#     214     cumulative_sum,
#     215     datetime64,
#     216     datetime_as_string,
#     217     datetime_data,
#     218     deg2rad,
#     219     degrees,
#     220     diagonal,
#     221     divide,
#     222     divmod,
#     223     dot,
#     224     double,
#     225     dtype,
#     226     e,
#     227     einsum,
#     228     einsum_path,
#     229     empty,
#     230     empty_like,
#     231     equal,
#     232     errstate,
#     233     euler_gamma,
#     234     exp,
#     235     exp2,
#     236     expm1,
#     237     fabs,
#     238     finfo,
#     239     flatiter,
#     240     flatnonzero,
#     241     flexible,
#     242     float16,
#     243     float32,
#     244     float64,
#     245     float_power,
#     246     floating,
#     247     floor,
#     248     floor_divide,
#     249     fmax,
#     250     fmin,
#     251     fmod,
#     252     format_float_positional,
#     253     format_float_scientific,
#     254     frexp,
#     255     from_dlpack,
#     256     frombuffer,
#     257     fromfile,
#     258     fromfunction,
#     259     fromiter,
#     260     frompyfunc,
#     261     fromstring,
#     262     full,
#     263     full_like,
#     264     gcd,
#     265     generic,
#     266     geomspace,
#     267     get_printoptions,
#     268     getbufsize,
#     269     geterr,
#     270     geterrcall,
#     271     greater,
#     272     greater_equal,
#     273     half,
#     274     heaviside,
#     275     hstack,
#     276     hypot,
#     277     identity,
#     278     iinfo,
#     279     indices,
#     280     inexact,
#     281     inf,
#     282     inner,
#     283     int8,
#     284     int16,
#     285     int32,
#     286     int64,
#     287     int_,
#     288     intc,
#     289     integer,
#     290     intp,
#     291     invert,
#     292     is_busday,
#     293     isclose,
#     294     isdtype,
#     295     isfinite,
#     296     isfortran,
#     297     isinf,
#     298     isnan,
#     299     isnat,
#     300     isscalar,
#     301     issubdtype,
#     302     lcm,
#     303     ldexp,
#     304     left_shift,
#     305     less,
#     306     less_equal,
#     307     lexsort,
#     308     linspace,
#     309     little_endian,
#     310     log,
#     311     log1p,
#     312     log2,
#     313     log10,
#     314     logaddexp,
#     315     logaddexp2,
#     316     logical_and,
#     317     logical_not,
#     318     logical_or,
#     319     logical_xor,
#     320     logspace,
#     321     long,
#     322     longdouble,
#     323     longlong,
#     324     matmul,
#     325     matrix_transpose,
#     326     matvec,
#     327     max,
#     328     maximum,
#     329     may_share_memory,
#     330     mean,
#     331     memmap,
#     332     min,
#     333     min_scalar_type,
#     334     minimum,
#     335     mod,
#     336     modf,
#     337     moveaxis,
#     338     multiply,
#     339     nan,
#     340     ndarray,
#     341     ndim,
#     342     nditer,
#     343     negative,
#     344     nested_iters,
#     345     newaxis,
#     346     nextafter,
#     347     nonzero,
#     348     not_equal,
#     349     number,
#     350     object_,
#     351     ones,
#     352     ones_like,
#     353     outer,
#     354     partition,
#     355     permute_dims,
#     356     pi,
#     357     positive,
#     358     pow,
#     359     power,
#     360     printoptions,
#     361     prod,
#     362     promote_types,
#     363     ptp,
#     364     put,
#     365     putmask,
#     366     rad2deg,
# --> 367     radians,
#     368     ravel,
#     369     recarray,
#     370     reciprocal,
#     371     record,
#     372     remainder,
#     373     repeat,
#     374     require,
#     375     reshape,
#     376     resize,
#     377     result_type,
#     378     right_shift,
#     379     rint,
#     380     roll,
#     381     rollaxis,
#     382     round,
#     383     sctypeDict,
#     384     searchsorted,
#     385     set_printoptions,
#     386     setbufsize,
#     387     seterr,
#     388     seterrcall,
#     389     shape,
#     390     shares_memory,
#     391     short,
#     392     sign,
#     393     signbit,
#     394     signedinteger,
#     395     sin,
#     396     single,
#     397     sinh,
#     398     size,
#     399     sort,
#     400     spacing,
#     401     sqrt,
#     402     square,
#     403     squeeze,
#     404     stack,
#     405     std,
#     406     str_,
#     407     subtract,
#     408     sum,
#     409     swapaxes,
#     410     take,
#     411     tan,
#     412     tanh,
#     413     tensordot,
#     414     timedelta64,
#     415     trace,
#     416     transpose,
#     417     true_divide,
#     418     trunc,
#     419     typecodes,
#     420     ubyte,
#     421     ufunc,
#     422     uint,
#     423     uint8,
#     424     uint16,
#     425     uint32,
#     426     uint64,
#     427     uintc,
#     428     uintp,
#     429     ulong,
#     430     ulonglong,
#     431     unsignedinteger,
#     432     unstack,
#     433     ushort,
#     434     var,
#     435     vdot,
#     436     vecdot,
#     437     vecmat,
#     438     void,
#     439     vstack,
#     440     where,
#     441     zeros,
#     442     zeros_like,
#     443 )
#     445 # NOTE: It's still under discussion whether these aliases
#     446 # should be removed.
#     447 for ta in ["float96", "float128", "complex192", "complex256"]:
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\char\__init__.py:1
# ----> 1 from numpy._core.defchararray import *
#       2 from numpy._core.defchararray import __all__, __doc__
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\_core\defchararray.py:23
#      21 from numpy._core import overrides
#      22 from numpy._core.multiarray import compare_chararrays
# ---> 23 from numpy._core.strings import (
#      24     _join as join,
#      25 )
#      26 from numpy._core.strings import (
#      27     _rsplit as rsplit,
#      28 )
#      29 from numpy._core.strings import (
#      30     _split as split,
#      31 )
#
# File ~\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\_core\strings.py:24
#      22 from numpy._core.multiarray import _vec_string
#      23 from numpy._core.overrides import array_function_dispatch, set_module
# ---> 24 from numpy._core.umath import (
#      25     _center,
#      26     _expandtabs,
#      27     _expandtabs_length,
#      28     _ljust,
#      29     _lstrip_chars,
#      30     _lstrip_whitespace,
#      31     _partition,
#      32     _partition_index,
#      33     _replace,
#      34     _rjust,
#      35     _rpartition,
#      36     _rpartition_index,
#      37     _rstrip_chars,
#      38     _rstrip_whitespace,
#      39     _slice,
#      40     _strip_chars,
#      41     _strip_whitespace,
#      42     _zfill,
#      43     isalnum,
#      44     isalpha,
#      45     isdecimal,
#      46     isdigit,
#      47     islower,
#      48     isnumeric,
#      49     isspace,
#      50     istitle,
#      51     isupper,
#      52     str_len,
#      53 )
#      54 from numpy._core.umath import (
#      55     count as _count_ufunc,
#      56 )
#      57 from numpy._core.umath import (
#      58     endswith as _endswith_ufunc,
#      59 )
#
# ImportError: cannot import name '_center' from 'numpy._core.umath' (C:\Users\moham\anaconda3\envs\pw-data-science\Lib\site-packages\numpy\_core\umath.py)

# %% [markdown]
# Here’s how you can write **Question 6** and its **answer** neatly in your assignment document:
# ### **Question 6:**
#
# **What is the Central Limit Theorem (CLT), and why is it critical in statistics?**
#
# ### **Answer:**
#
# The **Central Limit Theorem (CLT)** is one of the most important theorems in statistics. It states that when a large number of **independent and identically distributed (i.i.d.) random variables** are added together, their **sum (or average)** tends to follow a **normal distribution**, regardless of the original distribution of the data.
#
# In simple terms, **no matter what the shape of the population distribution is**, the distribution of the **sample mean** will approach a **normal distribution** as the sample size becomes large.
#
# ---
#
# ### **Mathematical Expression:**
#
# If ( X_1, X_2, ..., X_n ) are independent random variables with
#
# * mean ( \mu )
# * standard deviation ( \sigma ),
#
# then the sample mean ( \bar{X} ) approaches a normal distribution as ( n \to \infty ):
#
# [
# \bar{X} \sim N\left(\mu, \frac{\sigma^2}{n}\right)
# ]
#
# Or equivalently, the **Z-score**:
# [
# Z = \frac{\bar{X} - \mu}{\sigma / \sqrt{n}}
# ]
# follows a **standard normal distribution**.
#
# ---
#
# ### **Importance of the Central Limit Theorem:**
#
# 1. **Foundation for Inferential Statistics:**
#    It allows us to make statistical inferences about population parameters using sample data.
#
# 2. **Simplifies Analysis:**
#    Even when data is not normally distributed, CLT ensures that with a large enough sample, we can apply normal probability models.
#
# 3. **Used in Hypothesis Testing and Confidence Intervals:**
#    Many statistical methods (like Z-tests and t-tests) rely on the normal approximation provided by CLT.
#
# 4. **Enables Real-World Applications:**
#    Used in fields like finance, quality control, and data science to estimate probabilities and make predictions.
#
# ---
#
# ### **Python Example:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Population with a non-normal (uniform) distribution
population = np.random.uniform(0, 100, 100000)

sample_means = []
for _ in range(1000):
    sample = np.random.choice(population, 50)  # sample size = 50
    sample_means.append(np.mean(sample))

plt.hist(sample_means, bins=30, density=True)
plt.title("Demonstration of Central Limit Theorem")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()
